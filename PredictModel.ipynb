# %% [markdown]
# # From test prompts to LLM answers
#
# This notebook implements the execution of a scenario (prompts) designed in *stc-rdf-test*.
#
# Note : The code in the cells bellow should be added in a main function to be executed in command line.

# %%
import sys
print(sys.version)

# %%
import ollama
import pandas as pd
from pathlib import Path
from llms_classes import *
from prompt_classes import *
from dataset_classes import TextDataset

# %%
text_dataset=TextDataset()

# %%
text_dataset.filter_dataset_notclass()

# %%
prompt=PromptCreation()

# %%
resulting_prompt=prompt.prompt_creation()

# %%
for i in resulting_prompt:
    print(i)
# Out:
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: {}
# LABEL:

# %% [markdown]
# ## 2. Setup the Ollama server

# %% [markdown]
# Before executing this code, an Ollama server instance has to be launched in the terminal using the ```ollama serve``` command.

# %%
MODEL1 = "llama3.1"
MODEL= "mistral"
MODEL = "qwen2.5"

# %%
# Init the ollama server
ollama_server = OllamaServer(ollama)

# Check models that have already been downloaded
models = ollama_server.get_models_list()
print("Available Models:", models)

# Download the model to use for experiences
models = ollama_server.download_model_if_not_exists(MODEL)
# Out:
# Available Models: ['qwen2.5:latest', 'deepseek-r1:7b', 'llama3.2:3b', 'gemma2:2b', 'gemma2:latest', 'phi3.5:latest', 'llama3.1:latest', 'qwen2:latest', 'phi3:latest', 'tinyllama:latest', 'qwen2:1.5b', 'qwen2:0.5b', 'llama3:latest']
# qwen2.5 is already available in the server

# %% [markdown]
# ## 3. Execute the prompts

# %%
# Initialize the client and server
ollama_server = OllamaServer(ollama)

# Initialize chat with a specific model
chat = OllamaChat(server=ollama_server, model=MODEL)
# Out:
# qwen2.5 is already available in the server

# %%
LLM_Responses = []

for i in range(len(text_dataset.dataset_filter['TEXT'])):
    
    print("################## PROMPT #####################")
    print(resulting_prompt.to_list()[0].format(text_dataset.dataset_filter['TEXT'][i]))
    print("################## RESPONSE #####################")
    print("Pred")
    response = chat.send_prompt(resulting_prompt.to_list()[0], prompt_uuid="1", use_history=False, stream=True)
    print("\n")

    print("True")
    print(text_dataset.dataset_filter['Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+?'][i])
    print("\n")
    #LLM_Responses.append(response)
    #print(response.row_text)
# Out:
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: Il doodle di oggi è per un attivista LGBT anni 70. Travestito, viveva per strada dedito alla prostituzione, violento, aggressivo, mentalmente instabile e favoriva la prostituzione minorile... Se questi sono gli esempi per la comunità LGBT di oggi... (Fonte wikipedia)
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @dall_giovanni Per il resto, l'idea che esista un "conflitto" fra diritti delle notte e diritti trans è una puttanata che gira appunto agli aperitivi di Casapound e tra i terf.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Sostiene
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @godispog2 è transfobia specifica per gli uomini trans o le persone transmasc
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Sostiene
#
# True
# nan
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: Cortocircuito della logica femminista #pidiota.
#
# L’abuso dei diritti LGBT penalizza solo le donne: il trans ha la struttura fisica di un uomo.
#
# Non a caso nello sport esistono due categorie: quella maschile e femminile.👇🏼 https://t.co/5vcDind7ZN
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: "La mentalità di 1 uomo trans è diversa dall'uomo cisetero che non fa parte della comunità lgbt"
# Abbella sounds a little transfobic
# Che poi frega il cazzo se doveva essere un complimento, sempre una distinzione stai facendo
# Ad esempio io sono una testa di cazzo pure se son t***s
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Attacca
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: Sui diritti delle persone LGBTQ+ non si fanno passi avanti, le persone trans non esistono nel dibattito pubblico, la parità di genere è lontanissima. Ed è un problema anche per i diritti sociali, perché il versante culturale è sempre collegato a quello economico. @civati #Vasto https://t.co/JsLtspnQ5P
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT:
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: "Un'impresa essenziale dell'attivismo femminista, queer e trans è stata lo smantellamento di ideologie culturali, pratiche sociali e norme legali secondo cui alcune parti del corpo determinerebbero l'identità di genere e le caratteristiche e i ruoli sociali legati al genere. Ci
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: Io rispetto la gente che è di colore e la gente che è trans oppure che è bisessuale. Viva la LGBT #LGBT #LGBTQ #gay #trans #TransIsBeautiful
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: raga che hobby ho che non siano i soliti leggere scrivere di froci guardare video di uomini queer che mi spiegano la vita perché sono troppo fessa per capirla da sola
# solo che Olly non fa curriculum
# tristemente
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: #LGBTQIA #LGBTQ
# "Le lobby #LGBT"
# Già questa frase racchiude tutta la demenza di questi omofobi fascisti travestiti da conservatori.
# E quale sarebbe lo scopo di queste fantomatiche lobby? Il monopolio dei contraccettivi? La vendita di intimo multicolore?
# Ridicoli e infantili.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: io e il mio esercito di froci e amici LGBTQ che facciamo la rivoluzione nel mio paesello e cacciamo i preti omobitransfobici, misogini, sessisti, razzisti e anticomunisti https://t.co/RjRsxV7vp0
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: I DIRITTI TRANS SONO DIRITTI UMANI
# 🏳‍⚧🏳‍⚧🏳‍⚧🏳‍⚧🏳‍⚧🏳‍⚧🏳‍⚧
# #votate_oggi_DdlZAN
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: Uno degli argomenti dei trans-attivisti per una legge contro la “transfobia” sarebbero i tanti omicidi di trans. Le statistiche sono corrette?
# @STILLTish confronta gli omicidi di trans in UK con quelli di donne e con i crimini commessi da trans. https://t.co/NvOBIKqzXr
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: una donna trans nera, ce lo ha permesso. happy pride month, che quest’hanno come tutti gli anni è dedicato alla comunità nera e al movimento #BLACK_LIVES_MATTERS
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: se dopo che ti è stato fatto cat calling vieni aggredita perché trans si parla di transfobia, subisci transfobia non è più misoginia.
# non è una condizione peggiore o vissuta peggiore è una condizione diversa
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @cristinalattan2 @errico_erika Ao Cristì torna a sponsorizzare il pride che magari qualche buon trans che ti vende le mascherine lo trovi 🤣🤣🤣🤣🤣🤣🤣
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @hyuncr1 dovete smetterla di dire che tutto è transfobia lmao, tra uomini trans e uomini ci sono evidenti differenze come tra donne trans e donne
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Contraddittorio
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @sarafrancescalj La frase fatta è "ormai siamo pieni di froci" non la mia. Ovvero la traduzione del tuo Lgbt ecc ecc.
# Io sono etorosessuale ma non ho nessun fastidio dal Lgbt mi spaventano più quelli che vanno a messa e poi a trans di notte e scrivono frasi simili alle tue.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Neutrale
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @Vergorigo Newsweek: so' frocio pure io e il punto del discorso non era l'omofobia ma far notare ironicamente quanto sia tossico esibire corpi tonici millantando panze immaginarie. Vedo che con la comprensione del testo ci sono parecchi problemi. Ritenta, che sarai più fortunato.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Neutrale
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @psicolabilina stai invalidando una persona trans è letteralmente transfobia ci sei o ci fai?
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @ChrisGayfield No, ma ho visto altri membri della comunità LGBT insultare i trans e specie le persone non binarie perché non essere etero va bene, ma non essere cis è contronatura.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @acetilcoglione Lo sappiamo ma il problema è che i Pan credono di essere diversi facendo bifobia e transfobia considerando i trans meno uomini e donne. Poi se a te non dà fastidio che dei tizi possano dire "noi pan possiamo innamorarci di altri generi tipo i trans" buon per te
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @SamueleFrancioo Favorevole a matrimoni tra persone stesso sesso, adozioni per la comunità LGBT, sì aborto, sì eutanasia e sì alla legalizzazione della marijuana ahahaha
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# ...
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @ErTarni @PossibileIt @PossibileLGBTI @ILGAEurope @BenInLDN @vladiluxuria @CambrolleMar @PlataformaTrans @AlekosPrete @MattiaBBagnoli @fanpage La guerra peggiora ogni cosa specialmente per i gruppi sociali più fragili e sicuramente le persone trans rientrano tra questi.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: questa è transfobia, le persone trans non sono un genere a parte
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @MARlODRAGHI negro adesso che i froci continuano a non avere diritti possiamo tornare a parlare di farci le canne?
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: Mio padre la può finire ogni volta di dire orgoglioso checca o frocio per offendere ed insultare giuro che una sera mi incazzo non ce la faccio più
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: 🌈
# Esattamente un anno fa - in concomitanza con la giornata internazionale contro l'omofobia, la transfobia e la bifobia - #Taiwan diventa il primo Paese del continente asiatico a riconoscere i matrimoni tra persone dello stesso sesso.
# 🇹🇼🏳️‍🌈
# #IDAHOTB
# #IDAHOTB2020
# #LOVEisLOVE
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: Io e Mario gli agenti speciali pro LGBT su LoL pronti ad arrestare chiunque dica solo frocio o ometta l'esistenza di più gender...
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @HSkelsen Elementare. Una società che si occupa di diritti dei trans da 1 anno non si occupa del diritto di costruire una famiglia (cosa che per la verità e’ tale da vent’anni). Cosi in tv fa chic parlare del ddl Zan, fa bacchettone parlare di famiglia
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Contraddittorio
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @GianTressoldi Comeeeee chi è?
# Il grande senatore zan per intenderci leggi sui gay trans lesbiche lgbt e adozione bambini per e uomini
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: questo pride month non lo dedico a me stessa e alla mia sessualità ma a mia sorella trans che lotta ogni giorno per questo, love ya ❤️❤️
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @RebicIsTheWay Ihihih VaRDy spAccaTo banDierinA lGbt 🤣🤣🤣🤣 mito!!!! ke schf i froci
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @mircoDmirco Le auguro di cuore di trovare sempre la forza nella lotta contro il male, spesso travestito da "giusto diritto dell'individuo", che imperversa nelle società iper-secolarizzate e ultra-laiciste come la ns e che lei porta avanti anche con la sua testimonianza in questo social.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @ProgressistaIMB Speravo fosse più bello il mondo emancipato trans e queer mi rivolterei se fossi una di loro un modello così nemmeno morta !
# Vaccinatevi !
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Attacca
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: @Heartbeat_Noise Ti è andata bene...che poi sn le stesse che sentono i loro diritti di donna minacciati dai trans e dai gay...ok nn negare il sesso biologico ma un trans che toglie ai tuoi diritti? Sn delle pazze
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
#
#
# ################## PROMPT #####################
# Sei un classificatore di testi pubblicati su twitter (adesso X). Pensi che chi ha scritto la frase voglia attaccare, sostenere o essere neutrale verso la comunità LGBTQ+? Rispondi con un unica parola.
#
# INPUT: Meglio fascista che frocio? Sceglie fra due disgrazie. Sono contro l'omofobia, ma i froci non hanno mai mandato in Russia 67k mila ragazzi senza equipaggiamento, dei quali solo 7k tornati ma congelati, fra cui mio nonno. E' fiera di suo nonno che ha fatto questo  e .... vergogna!
# LABEL: Attacca
#
# INPUT: @Rosi33998582 @mps274 No. Questo è un insulto lesbica no LGBT sta per Lesbica Gay Bisessuali Trans usare la parola froc*o ha una connotazione dispregiativa come lo è diventata neg*o che invece prima si usava ( se sbaglio correggetemi per favore ).
# LABEL: Sostiene
#
# INPUT: gay, lesbiche, bi e trans a raccolta andiamo a bruciare le chiese e gli studi mediaset.
# essere LGBT non è una scelta, ma l'incendio doloso sì.
# LABEL:
#
# ################## RESPONSE #####################
# Pred
# Neutrale
#
# True
# Sostiene
